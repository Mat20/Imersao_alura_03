# %%
import pandas as pd

url_dados = 'https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true'

dados = pd.read_csv(url_dados, compression = 'zip')
dados
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %% [markdown]
# # Desafio 01: Investigar por que a classe tratamento é tão desbalanceada.
# # Desafio 02: Plotar as 5 últimas linhas da tabela.
# # Desafio 03: Proporção das classes tratamento.
# # Desafio 04: Quantos tipos de drogas foram investigados.
# # Desafio 05: Procurar na documentação o método query(pandas).
# # Desafio 06: Renomear as colunas tirando o hífen.
# # Desafio 07: Deixar os gráficos bonitões. (Matplotlib.pyplot)
# # Desafio 08: Resumo do que vcê aprendeu com dados.

# %% [markdown]
# # Desafio 01

# %%
dados[dados.tratamento == 'com_controle'].droga.unique()
# Out:
# array(['cacb2b860'], dtype=object)

# %%
dados[dados.tratamento == 'com_droga'].droga.unique()
# Out:
# array(['b68db1d53', 'df89a8e5a', '18bb41b2c', ..., '573c787a2',
#        'b2fe3eca7', 'dd4a96d16'], dtype=object)

# %% [markdown]
# # Desafo 02

# %%
#Api Pandas https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.tail.html#
dados.tail()
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# 23813  id_ffffdd77b     com_droga     72   D1  ... -3.5770 -0.4775 -2.1500 -4.2520
#
# [5 rows x 877 columns]

# %% [markdown]
# # Desafio 03

# %%
# value_counts feito durante a aula
dados['tratamento'].value_counts(normalize = True)
# Out:
# com_droga       0.921643
# com_controle    0.078357
# Name: tratamento, dtype: float64

# %% [markdown]
# # Desafio 04

# %%
drogas = dados['droga'].nunique()
print(f'Numeros de Drogas investigados {drogas} tipos de drogas')
# Out:
# Numeros de Drogas investigados 3289 tipos de drogas

# %% [markdown]
# # Desafio 05

# %%
dados[dados.tempo == 72].tail()
# Out:
#                  id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 23797  id_ffe6452ba  com_droga     72   D2  ... -0.1795  0.0287  0.8309  1.1490
# 23798  id_fff11dbf5  com_droga     72   D2  ... -0.4231 -0.1848  0.5300 -0.1913
# 23800  id_fff1a3307  com_droga     72   D2  ...  0.3823  0.8707  0.8011  0.4942
# 23808  id_fff8c2444  com_droga     72   D1  ... -0.7415  0.8413 -0.4259  0.2434
# 23813  id_ffffdd77b  com_droga     72   D1  ... -3.5770 -0.4775 -2.1500 -4.2520
#
# [5 rows x 877 columns]

# %%
dados[dados['tempo'] == 72].tail()
# Out:
#                  id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 23797  id_ffe6452ba  com_droga     72   D2  ... -0.1795  0.0287  0.8309  1.1490
# 23798  id_fff11dbf5  com_droga     72   D2  ... -0.4231 -0.1848  0.5300 -0.1913
# 23800  id_fff1a3307  com_droga     72   D2  ...  0.3823  0.8707  0.8011  0.4942
# 23808  id_fff8c2444  com_droga     72   D1  ... -0.7415  0.8413 -0.4259  0.2434
# 23813  id_ffffdd77b  com_droga     72   D1  ... -3.5770 -0.4775 -2.1500 -4.2520
#
# [5 rows x 877 columns]

# %%
dados.query('tempo == 72').tail()
# Out:
#                  id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 23797  id_ffe6452ba  com_droga     72   D2  ... -0.1795  0.0287  0.8309  1.1490
# 23798  id_fff11dbf5  com_droga     72   D2  ... -0.4231 -0.1848  0.5300 -0.1913
# 23800  id_fff1a3307  com_droga     72   D2  ...  0.3823  0.8707  0.8011  0.4942
# 23808  id_fff8c2444  com_droga     72   D1  ... -0.7415  0.8413 -0.4259  0.2434
# 23813  id_ffffdd77b  com_droga     72   D1  ... -3.5770 -0.4775 -2.1500 -4.2520
#
# [5 rows x 877 columns]

# %% [markdown]
# # Desafio 06

# %%
sem_hifen = dados.rename(columns = lambda coluna: coluna.replace('-', ''))
sem_hifen.columns
# Out:
# Index(['id', 'tratamento', 'tempo', 'dose', 'droga', 'g0', 'g1', 'g2', 'g3',
#        'g4',
#        ...
#        'c90', 'c91', 'c92', 'c93', 'c94', 'c95', 'c96', 'c97', 'c98', 'c99'],
#       dtype='object', length=877)

# %% [markdown]
# # Desafio 07

# %%
dados.tempo.value_counts(ascending = True).plot.bar(
    #color = '#6600cc',
    #color = '#660033',
    color = '#99ff33',
    fontsize = 13,
    title = 'Doses',
    rot = 0,
    xlabel = 'Tempo HR(horas)',
    ylabel = 'Número de observações'
)

# %%
dados.tratamento.value_counts().plot.pie(autopct = "%.2f%%", colors = ['#ff1aff' , '#ff3300' ])

# %% [markdown]
# # Desafio 08
#
#
# Bom aprendir muito coisa: sobre como passa cor com as funções, entendedo mais sobre o panda, vir em alguns canais do Youtube, mas não fui a fundo.E o python em data science e muito dinâmico. Gostei muito da explicação da Vanessa Leiko sobre RNA .... e o Thiado G. Santos e Guilherme Silveira show de bola....
